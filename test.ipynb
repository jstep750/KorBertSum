# %%
import pandas as pd
pd.read_csv('./src/preprocessed/raws/bertopic(mpnet)/bertopic_부동산_20221201_20221215_pre.csv')
# Out:
#      Unnamed: 0                                              title  \
# 0           631               한은  자금 채권시장 불안 재연 가능성 시장안정화 대책 강구 필요
# 1           760  한은  채권시장 안정 찾겠지만 리스크 상존 금융사 도덕적 해이 유의해야   통화신용...
# 2           112                        금융당국, 부동산 PF ABCP 기초자산까지 본다
# 3           294                           금융당국, 부동산PF 기초자산까지 들여다본다
# 4           672             주산연  내년 건설사 부도 속출땐 2금융권도 부실 미분양 대책 내놔야
# ..          ...                                                ...
# 117         169                           미국의 금리 인상과 부동산 시장에서 본 교훈
# 118         890                           매매로 제값 못 받으니 차라리  헐값  증여
# 119         574                        청년층 청약 당첨 유리해진다 규제지역 추첨제 확대
# 120         983       2030 당첨 잘 되려나 내년 4월부터 서울 중소형 아파트 60% 추첨제로 공급
# 121         347                         익산시, 신혼부부 청년 임차보증금 이자지원 확대
#
#                                            description  \
# 0    한국은행은 레고랜드발 사태로 촉발된 국내 기업어음 CP  신용채권 시장 불안이 정부...
# ...

# %%
import time
import pandas as pd
import torch
from transformers import PreTrainedTokenizerFast
from transformers import BartForConditionalGeneration


tokenizer = PreTrainedTokenizerFast.from_pretrained('digit82/kobart-summarization')
model = BartForConditionalGeneration.from_pretrained('digit82/kobart-summarization')

# %%
import time
import pandas as pd
import torch
from transformers import PreTrainedTokenizerFast
from transformers import BartForConditionalGeneration

tokenizer = PreTrainedTokenizerFast.from_pretrained('digit82/kobart-summarization')
model = BartForConditionalGeneration.from_pretrained('digit82/kobart-summarization')

summary = []
for i in range(len(df)):
    text = df['context'][i][:512]
    #text = text.replace('\n', ' ')
    start = time.time()
    raw_input_ids = tokenizer.encode(text)
    input_ids = [tokenizer.bos_token_id] + raw_input_ids + [tokenizer.eos_token_id]

    summary_ids = model.generate(torch.tensor([input_ids]),  num_beams=4,  max_length=512, min_length=64,  eos_token_id=1)
    print(f"{i}: {time.time()-start:.4f} sec")
    sum_result = tokenizer.decode(summary_ids.squeeze().tolist(), skip_special_tokens=True)
    print(sum_result)
    summary.append(sum_result)
# Out:
# 0: 1.5158 sec
# 13일부터 삼성전자는 스마트폰으로 동영상 촬영 시 전방위서 들려오는 소리를 녹음할 수 있도록 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행한다고 밝혔으며 버즈2 프로 좌우에 있는 마이크가 모두 사용돼 360도에서 들려오는 소리를 플립4·폴드4로 녹음할 수 있다.
# 1: 1.4351 sec
# 삼성전자는 13 버즈2 프로와 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행하여 스마트폰 동영상 촬영 시 360도 사운드 녹음이 가능하도록 갤럭시 버즈2 프로 좌우에 있는 마이크가 모두 사용돼 360도에서 들려오는 소리를 플립4·폴드4로 녹음할 수 있다.
# 2: 1.3425 sec
# 삼성전자가 13 스마트폰으로 동영상 촬영 시 전방위서 들려오는 소리를 녹음할 수 있도록 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행하며, 다음 달 진행되는 갤럭시 언팩에서 새로운 갤럭시 스마트폰과 관련된 더 많은 내용을 소개할 예정이다.
# 3: 1.4385 sec
# 삼성전자는 스마트폰으로 스마트폰으로 동영상 촬영 시 전방위에서 들려오는 소리를 녹음할 수 있도록 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 시행한다고 13일 밝혔으며 내달 중 갤럭시 워치5와 워치4 시리즈에 카메라 줌 인과 줌 아웃 기능도 추가할 예정이다.
# 4: 1.3496 sec
# 삼성전자는 휴대전화로 동영상을 찍을 때 360도 사운드 녹음이 가능하도록 갤럭시 버즈2 프로와 갤럭시Z 플립4, 폴드4의 소프트웨어 업데이트를 시행한다고 밝혔으며 소프트웨어 업데이트를 통해 버즈2 프로 좌우에 있는 마이크로 사용자가 듣는 그대로의 소리를 생생하게 녹음할 수 있다고 밝혔다.

# %%
print(summary)
# Out:
# ['13일부터 삼성전자는 스마트폰으로 동영상 촬영 시 전방위서 들려오는 소리를 녹음할 수 있도록 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행한다고 밝혔으며 버즈2 프로 좌우에 있는 마이크가 모두 사용돼 360도에서 들려오는 소리를 플립4·폴드4로 녹음할 수 있다.', '삼성전자는 13 버즈2 프로와 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행하여 스마트폰 동영상 촬영 시 360도 사운드 녹음이 가능하도록 갤럭시 버즈2 프로 좌우에 있는 마이크가 모두 사용돼 360도에서 들려오는 소리를 플립4·폴드4로 녹음할 수 있다.', '삼성전자가 13 스마트폰으로 동영상 촬영 시 전방위서 들려오는 소리를 녹음할 수 있도록 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행하며, 다음 달 진행되는 갤럭시 언팩에서 새로운 갤럭시 스마트폰과 관련된 더 많은 내용을 소개할 예정이다.     ', '삼성전자는 스마트폰으로 스마트폰으로 동영상 촬영 시 전방위에서 들려오는 소리를 녹음할 수 있도록 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 시행한다고 13일 밝혔으며 내달 중 갤럭시 워치5와 워치4 시리즈에 카메라 줌 인과 줌 아웃 기능도 추가할 예정이다.', '삼성전자는 휴대전화로 동영상을 찍을 때 360도 사운드 녹음이 가능하도록 갤럭시 버즈2 프로와 갤럭시Z 플립4, 폴드4의 소프트웨어 업데이트를 시행한다고 밝혔으며 소프트웨어 업데이트를 통해 버즈2 프로 좌우에 있는 마이크로 사용자가 듣는 그대로의 소리를 생생하게 녹음할 수 있다고 밝혔다.']

# %%
import random
summ = summary
random.shuffle(summ)

# %%
text = '\n'.join(summ)
start = time.time()
raw_input_ids = tokenizer.encode(text)
input_ids = [tokenizer.bos_token_id] + raw_input_ids + [tokenizer.eos_token_id]

summary_ids = model.generate(torch.tensor([input_ids]),  num_beams=4,  max_length=512, min_length=100,  eos_token_id=1)
print(f"{time.time()-start:.4f} sec")
sum_result = tokenizer.decode(summary_ids.squeeze().tolist(), skip_special_tokens=True)
print(sum_result)
summary.append(sum_result)
# Out:
# 3.1324 sec
# 삼성전자는 13 스마트폰으로 동영상 촬영 시 360도 사운드 녹음이 가능하도록 갤럭시 버즈2 프로와 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행한다고 밝혔으며 내달 중 갤럭시 워치5와 워치4 시리즈에 카메라 줌 인과 줌 아웃 기능도 추가할 예정이다.                     삼성전자는 13일부터 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 시행한다고 밝혔으며 소프트웨어 업데이트를 통해 버즈2 프로 좌우에 있는 마이크가 모두 사용돼 360도에서 들려오는 소리를 녹음할 수 있다고 밝혔다.

# %%
import time
import pandas as pd
import torch
from transformers import PreTrainedTokenizerFast
from transformers import BartForConditionalGeneration

tokenizer = PreTrainedTokenizerFast.from_pretrained('digit82/kobart-summarization')
model = BartForConditionalGeneration.from_pretrained('digit82/kobart-summarization')
df = pd.read_csv('./result10.csv')

summary = []
for i in range(len(df)):
    text = df['context'][i][:512]
    #text = text.replace('\n', ' ')
    start = time.time()
    raw_input_ids = tokenizer.encode(text)
    input_ids = [tokenizer.bos_token_id] + raw_input_ids + [tokenizer.eos_token_id]

    summary_ids = model.generate(torch.tensor([input_ids]),  num_beams=4,  max_length=512, min_length=64,  eos_token_id=1)
    print(f"{i}: {time.time()-start:.4f} sec")
    sum_result = tokenizer.decode(summary_ids.squeeze().tolist(), skip_special_tokens=True)
    print(sum_result)
    summary.append(sum_result)
# Out:
# 0: 1.5187 sec
# 13일부터 삼성전자는 스마트폰으로 동영상 촬영 시 전방위서 들려오는 소리를 녹음할 수 있도록 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행한다고 밝혔으며 버즈2 프로 좌우에 있는 마이크가 모두 사용돼 360도에서 들려오는 소리를 플립4·폴드4로 녹음할 수 있다.
# 1: 1.5548 sec
# 삼성전자는 13 버즈2 프로와 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행하여 스마트폰 동영상 촬영 시 360도 사운드 녹음이 가능하도록 갤럭시 버즈2 프로 좌우에 있는 마이크가 모두 사용돼 360도에서 들려오는 소리를 플립4·폴드4로 녹음할 수 있다.
# 2: 1.3293 sec
# 삼성전자가 13 스마트폰으로 동영상 촬영 시 전방위서 들려오는 소리를 녹음할 수 있도록 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행하며, 다음 달 진행되는 갤럭시 언팩에서 새로운 갤럭시 스마트폰과 관련된 더 많은 내용을 소개할 예정이다.
# 3: 1.4296 sec
# 삼성전자는 스마트폰으로 스마트폰으로 동영상 촬영 시 전방위에서 들려오는 소리를 녹음할 수 있도록 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 시행한다고 13일 밝혔으며 내달 중 갤럭시 워치5와 워치4 시리즈에 카메라 줌 인과 줌 아웃 기능도 추가할 예정이다.
# 4: 1.3375 sec
# 삼성전자는 휴대전화로 동영상을 찍을 때 360도 사운드 녹음이 가능하도록 갤럭시 버즈2 프로와 갤럭시Z 플립4, 폴드4의 소프트웨어 업데이트를 시행한다고 밝혔으며 소프트웨어 업데이트를 통해 버즈2 프로 좌우에 있는 마이크로 사용자가 듣는 그대로의 소리를 생생하게 녹음할 수 있다고 밝혔다.
# 5: 1.8440 sec
# ...

# %%
print(len(summ))
# Out:
# 10

# %%
summary = summ
random.shuffle(summary)
print('-----------------------------------------------')
num = 4
while(len(summary) > num):
    summary2 = summary[:num]
    summary = summary[num:]
    text = '\n'.join(summary2)
    start = time.time()
    raw_input_ids = tokenizer.encode(text)
    input_ids = [tokenizer.bos_token_id] + raw_input_ids + [tokenizer.eos_token_id]

    summary_ids = model.generate(torch.tensor([input_ids]),  num_beams=4,  max_length=512, min_length=64,  eos_token_id=1)
    print(f"{time.time()-start:.4f} sec")
    sum_result = tokenizer.decode(summary_ids.squeeze().tolist(), skip_special_tokens=True)
    print(sum_result)
    summary.append(sum_result)
    print(len(summary))
    print('-----------------------------------------------')

text = '\n'.join(summary)
start = time.time()
raw_input_ids = tokenizer.encode(text)
input_ids = [tokenizer.bos_token_id] + raw_input_ids + [tokenizer.eos_token_id]

summary_ids = model.generate(torch.tensor([input_ids]),  num_beams=4,  max_length=512, min_length=100,  eos_token_id=1)
print(f"{time.time()-start:.4f} sec")
sum_result = tokenizer.decode(summary_ids.squeeze().tolist(), skip_special_tokens=True)
print(sum_result)
summary.append(sum_result)
# Out:
# -----------------------------------------------
# 1.7975 sec
# 삼성전자는 갤럭시 버즈2 프로 착용자는 Z 플립4·폴드4로 동영상을 촬영하면 본인이 듣는 소리 자체를 녹음을 할 수 있고 갤럭시 버즈2 프로 좌우의 마이크가 360도 사운드를 포착하기 때문에 차세대 블루투스 오디오 기술 표준인 LE 오디오를 적용하여 차세대 블루투스 오디오 기술 표준인 LE 오디오를 적용했다고 밝혔다.
# 7
# -----------------------------------------------
# 1.9644 sec
# 삼성전자가 스마트폰 스마트폰과 웨어러블 기기의 연동을 강화해 카메라 사용성을 개선하기 위해 무선어폰 '갤럭시 버즈2 프로'와 스마트폰 갤럭시Z플립4·폴드4의 소프트웨어 업데이트를 시행한다고 밝혔으며 삼성전자는 스마트폰 동영상 촬영 시 360도 사운드 녹음이 가능하도록 무선어폰 '갤럭시 버즈2 프로'와 스마트폰 갤럭시Z플립4·폴드4의 소프트웨어 업데이트를 시행한다고 밝혔다.
# 4
# -----------------------------------------------
# 2.7844 sec
# 삼성전자가 13 13 스마트폰으로 동영상 촬영 시 전방위서 들려오는 소리를 녹음할 수 있도록 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행하며, 다음 달 진행되는 갤럭시 언팩에서 새로운 갤럭시 스마트폰과 관련된 더 많은 내용을 소개할 예정이다.
# 삼성전자는 휴대전화로 동영상을 찍을 때 360도 사운드 녹음이 가능하도록 갤럭시 버즈2 프로와 갤럭시Z 플립4, 폴드4의 소프트웨어 업데이트를 시행한다고 밝혔으며 소프트웨어 업데이트를 통해 버즈2 프로 좌우에 있는 마이크로 사용자가 듣는 그대로의 소리를 생생하게 녹음할 수 있다고 밝혔다.

# %%
import time
import torch
from transformers import AutoTokenizer, AutoModelWithLMHead
tokenizer = AutoTokenizer.from_pretrained('psyche/KoT5-paraphrase-generation')
model = AutoModelWithLMHead.from_pretrained('psyche/KoT5-paraphrase-generation')

text = '\n'.join(summary)
print(text)
print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
start = time.time()
input_ids = tokenizer.encode(text, return_tensors="pt", add_special_tokens=True)
generated_ids = model.generate(input_ids=input_ids, num_return_sequences=5, num_beams=5, max_length=512, min_length=128, no_repeat_ngram_size=2, repetition_penalty=3.5, length_penalty=1.0, early_stopping=True)
print(tokenizer.decode(generated_ids[0], skip_special_tokens=True, clean_up_tokenization_spaces=True))
print(f"{time.time()-start:.4f} sec")
# Out:
# 13일부터 삼성전자는 스마트폰으로 동영상 촬영 시 전방위서 들려오는 소리를 녹음할 수 있도록 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행한다고 밝혔으며 버즈2 프로 좌우에 있는 마이크가 모두 사용돼 360도에서 들려오는 소리를 플립4·폴드4로 녹음할 수 있다.
# 삼성전자는 13 버즈2 프로와 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행하여 스마트폰 동영상 촬영 시 360도 사운드 녹음이 가능하도록 갤럭시 버즈2 프로 좌우에 있는 마이크가 모두 사용돼 360도에서 들려오는 소리를 플립4·폴드4로 녹음할 수 있다.
# 삼성전자가 13 스마트폰으로 동영상 촬영 시 전방위서 들려오는 소리를 녹음할 수 있도록 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행하며, 다음 달 진행되는 갤럭시 언팩에서 새로운 갤럭시 스마트폰과 관련된 더 많은 내용을 소개할 예정이다.
# 삼성전자는 스마트폰으로 스마트폰으로 동영상 촬영 시 전방위에서 들려오는 소리를 녹음할 수 있도록 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 시행한다고 13일 밝혔으며 내달 중 갤럭시 워치5와 워치4 시리즈에 카메라 줌 인과 줌 아웃 기능도 추가할 예정이다.
# 삼성전자는 휴대전화로 동영상을 찍을 때 360도 사운드 녹음이 가능하도록 갤럭시 버즈2 프로와 갤럭시Z 플립4, 폴드4의 소프트웨어 업데이트를 시행한다고 밝혔으며 소프트웨어 업데이트를 통해 버즈2 프로 좌우에 있는 마이크로 사용자가 듣는 그대로의 소리를 생생하게 녹음할 수 있다고 밝혔다.
# ...

# %%
import time
import pandas as pd
import torch
from transformers import PreTrainedTokenizerFast
from transformers import BartForConditionalGeneration

tokenizer = PreTrainedTokenizerFast.from_pretrained('digit82/kobart-summarization')
model = BartForConditionalGeneration.from_pretrained('digit82/kobart-summarization')
df = pd.read_csv('./result30.csv')

summary = []
for i in range(len(df)):
    text = df['context'][i][:512]
    #text = text.replace('\n', ' ')
    start = time.time()
    raw_input_ids = tokenizer.encode(text)
    input_ids = [tokenizer.bos_token_id] + raw_input_ids + [tokenizer.eos_token_id]

    summary_ids = model.generate(torch.tensor([input_ids]),  num_beams=4,  max_length=512, min_length=64,  eos_token_id=1)
    print(f"{i}: {time.time()-start:.4f} sec")
    sum_result = tokenizer.decode(summary_ids.squeeze().tolist(), skip_special_tokens=True)
    print(sum_result)
    summary.append(sum_result)
print(summary)
# Out:
# 0: 1.4565 sec
# 13일부터 삼성전자는 스마트폰으로 동영상 촬영 시 전방위서 들려오는 소리를 녹음할 수 있도록 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행한다고 밝혔으며 버즈2 프로 좌우에 있는 마이크가 모두 사용돼 360도에서 들려오는 소리를 플립4·폴드4로 녹음할 수 있다.
# 1: 1.4355 sec
# 삼성전자는 13 버즈2 프로와 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행하여 스마트폰 동영상 촬영 시 360도 사운드 녹음이 가능하도록 갤럭시 버즈2 프로 좌우에 있는 마이크가 모두 사용돼 360도에서 들려오는 소리를 플립4·폴드4로 녹음할 수 있다.
# 2: 1.3431 sec
# 삼성전자가 13 스마트폰으로 동영상 촬영 시 전방위서 들려오는 소리를 녹음할 수 있도록 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행하며, 다음 달 진행되는 갤럭시 언팩에서 새로운 갤럭시 스마트폰과 관련된 더 많은 내용을 소개할 예정이다.
# 3: 1.3953 sec
# 삼성전자는 스마트폰으로 스마트폰으로 동영상 촬영 시 전방위에서 들려오는 소리를 녹음할 수 있도록 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 시행한다고 13일 밝혔으며 내달 중 갤럭시 워치5와 워치4 시리즈에 카메라 줌 인과 줌 아웃 기능도 추가할 예정이다.
# 4: 1.3104 sec
# 삼성전자는 휴대전화로 동영상을 찍을 때 360도 사운드 녹음이 가능하도록 갤럭시 버즈2 프로와 갤럭시Z 플립4, 폴드4의 소프트웨어 업데이트를 시행한다고 밝혔으며 소프트웨어 업데이트를 통해 버즈2 프로 좌우에 있는 마이크로 사용자가 듣는 그대로의 소리를 생생하게 녹음할 수 있다고 밝혔다.
# 5: 1.8134 sec
# ...

# %%
summary3 = summary

# %%
summary = summary3
len(summary)
# Out:
# 30

# %%
print('-----------------------------------------------')
num = 8
while(len(summary) >num):
    summary2 = summary[:num]
    summary = summary[num:]
    text = '\n'.join(summary2)
    start = time.time()
    raw_input_ids = tokenizer.encode(text)
    input_ids = [tokenizer.bos_token_id] + raw_input_ids + [tokenizer.eos_token_id]

    summary_ids = model.generate(torch.tensor([input_ids]),  num_beams=4,  max_length=512, min_length=64,  eos_token_id=1)
    print(f"{time.time()-start:.4f} sec")
    sum_result = tokenizer.decode(summary_ids.squeeze().tolist(), skip_special_tokens=True)
    print(sum_result)
    summary.append(sum_result)
    print(len(summary))
    print('-----------------------------------------------')

text = '\n'.join(summary)
start = time.time()
raw_input_ids = tokenizer.encode(text)
input_ids = [tokenizer.bos_token_id] + raw_input_ids + [tokenizer.eos_token_id]

summary_ids = model.generate(torch.tensor([input_ids]),  num_beams=4,  max_length=512, min_length=100,  eos_token_id=1)
print(f"{time.time()-start:.4f} sec")
sum_result = tokenizer.decode(summary_ids.squeeze().tolist(), skip_special_tokens=True)
print(sum_result)
summary.append(sum_result)
# Out:
# -----------------------------------------------
# 1.6166 sec
# 삼성전자는 13 스마트폰으로 동영상 촬영 시 전방위서 들려오는 소리를 녹음할 수 있도록 갤럭시 버즈2 프로 및 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 13일부터 시행한다고 밝혔으며 다음 달 진행되는 갤럭시 언팩에서 새로운 갤럭시 스마트폰과 관련된 더 많은 내용을 소개할 예정이다.
#
# 23
# -----------------------------------------------
# 1.7313 sec
# 13일 삼성전자는전자는 갤럭시 동영상 촬영 시 360도 사운드 녹음이 가능하도록 갤럭시버즈2 프로와 갤럭시Z플립4·폴드4의 소프트웨어 업데이트를 실시한다고 밝혔으며 갤럭시워치5와 워치4 시리즈의 소프트웨어 업데이트를 통해 스마트폰 카메라를 원격으로 줌인·줌아웃할 수 있는 기능도 추가하였다.
# 16
# -----------------------------------------------
# 3.1127 sec
# 13일 삼성전자는전자가 13일 스마트폰 동영상 촬영 시 360도 사운드 녹음이 가능하도록 갤럭시 버즈2 프로와 갤럭시 Z 플립4·폴드4의 소프트웨어 업데이트를 시행한다고 밝혔으며 버즈2 프로의 좌우 마이크를 모두 사용해 이용자가 듣는 그대로의 몰입형 사운드를 녹음할 수 있다고 밝혔다.
# 삼성전자가 2월 스마트폰 카메라 사용성 향상을 위해 2월 중 기존의 워치 카메라 컨트롤러 앱에 카메라 '줌 인 줌 아웃' 기능을 추가하는 소프트웨어 업데이트를 진행한다고 밝혔으며 갤럭시 워치 4·5와 갤럭시 버즈2 프로는 360 오디오 레코딩 기능을 대상으로 소프트웨어 업데이트를 진행한다고 밝혔다.
# 9
# -----------------------------------------------
# 2.3218 sec
# ...
